# %% [markdown]
# ## EDA on Haberman Cancer-Survival-DataSet

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Importing data set firstly -

# %%
haberman = pd.read_csv('/media/rahul0324/Disk-D/Applied_Dataset/Haberman-Dataset/haberman.csv')

# %%
haberman.head()
# Out:
#    30  64   1  1.1
# 0  30  62   3    1
# 1  30  65   0    1
# 2  31  59   2    1
# 3  31  65   4    1
# 4  33  58  10    1

# %%
haberman.shape
# Out:
# (305, 4)

# %% [markdown]
# From the above output it's clear that there are 305 rows and 4 columns.

# %% [markdown]
# Acording to kaggle haberman dataset it's said that the 1st column is patient age, 2nd column is operation year, 3rd column is no. of positive axillary nodes and the last column tells us patient survival status:
#
# If the survival status is 1 -
#
#     then the patient survived 5 years or longer
#
# If the survival status is 2 -
#
#     then the patient died within 5 year

# %%
haberman.columns
# Out:
# Index(['30', '64', '1', '1.1'], dtype='object')

# %% [markdown]
# Now firstly lets rename the column with appropriate names-

# %%
df = haberman.rename(columns={"30":"ptent_age", "64":"oper_yr", "1":"axillary_nodes", "1.1":"survival_status"})

# %%
df.shape
# Out:
# (305, 4)

# %%
df.columns
# Out:
# Index(['ptent_age', 'oper_yr', 'axillary_nodes', 'survival_status'], dtype='object')

# %% [markdown]
# It's clear from the above output that there are 3 features and we have to find out the survial status

# %%
df.head()
# Out:
#    ptent_age  oper_yr  axillary_nodes  survival_status
# 0         30       62               3                1
# 1         30       65               0                1
# 2         31       59               2                1
# 3         31       65               4                1
# 4         33       58              10                1

# %%
df.tail()
# Out:
#      ptent_age  oper_yr  axillary_nodes  survival_status
# 300         75       62               1                1
# 301         76       67               0                1
# 302         77       65               3                1
# 303         78       65               1                2
# 304         83       58               2                2

# %% [markdown]
# Now firstly lets change the survival status as yes or no, yes means 1 and no means 2 -

# %%
df['survival_status'] = df['survival_status'].map({1:"yes", 2:"no"})

# %%
df.tail()
# Out:
#      ptent_age  oper_yr  axillary_nodes survival_status
# 300         75       62               1             yes
# 301         76       67               0             yes
# 302         77       65               3             yes
# 303         78       65               1              no
# 304         83       58               2              no

# %%
df.head()
# Out:
#    ptent_age  oper_yr  axillary_nodes survival_status
# 0         30       62               3             yes
# 1         30       65               0             yes
# 2         31       59               2             yes
# 3         31       65               4             yes
# 4         33       58              10             yes

# %%
df['survival_status'].value_counts()
# Out:
# yes    224
# no      81
# Name: survival_status, dtype: int64

# %% [markdown]
# It's clear that there are 2 class (i.e yes or no) and yes class have 224 data points and no class have 81 data points.

# %% [markdown]
# ## Objective -
#       We have to classify that after giving patient_age, operation_year and no. of positive axillary nodes
#       whether patient survive (5 years or longer) or less than 5 years.

# %% [markdown]
# ## Univariate Analysis -

# %%
sns.FacetGrid(df, hue = 'survival_status', height = 5)\
   .map(sns.distplot, "ptent_age")\
   .add_legend()                                        # this graph is based on patient_age
plt.show()

# %%
sns.FacetGrid(df, hue = "survival_status", height = 5)\
   .map(sns.distplot, "oper_yr")\
   .add_legend()                                        # this graph is based on operation year
plt.show()

# %%
sns.FacetGrid(df, hue = "survival_status", height = 5)\
   .map(sns.distplot, "axillary_nodes")\
   .add_legend()                                    # this graph is based on number of positive axillary nodes-
plt.show()

# %% [markdown]
# So from the above graph it's clear that number of axillary nodes feature is more important than others -

# %% [markdown]
# ## Now let's see box plot of all the features

# %%
sns.boxplot(x = "survival_status", y = "axillary_nodes", data = df)
plt.show()
sns.boxplot(x = "survival_status", y = "ptent_age", data = df)
plt.show()
sns.boxplot(x = "survival_status", y = "oper_yr", data = df)
plt.show()

# %% [markdown]
# <b>From the above graph it's clear that patient whose surgery is done before 1960 are having very less chances of survive more than 5 years and the patient whose surgery is done after 1965 have higher chances of surviving more than 5 years.</b>

# %% [markdown]
# ## Lets see violin plots

# %%
sns.violinplot(x = "survival_status", y = "axillary_nodes", data = df, size = 8)
plt.show()
sns.violinplot(x = "survival_status", y = "ptent_age", data = df, size = 8)
plt.show()
sns.violinplot(x = "survival_status", y = "oper_yr", data = df, size = 8)
plt.show()

# %% [markdown]
# ## Observation -
#
# 1. Patient whose treatment year is below 1960 are having lesser chance of surviving more than 5 years and whose treatment year is more than 1965 are having higher chances of surviving more than 5 years.
# 2. First grpah is highly densed between 0 to 4.5(aprox) means maximum patient having positive axillary nodes is between 0 and 5.

# %% [markdown]
# so, let's see some bi-variate analysis -

# %% [markdown]
# ## Scatter plots -

# %%
df.plot(kind = "scatter", x = "axillary_nodes", y = "ptent_age")
plt.show()

# %%
df.plot(kind = "scatter", x = "ptent_age", y = "axillary_nodes")
plt.show()

# %% [markdown]
# Since we can't find anything by seeing like this so let's differentiate the survival status using coloring -

# %%
sns.set_style("whitegrid")
sns.FacetGrid(df, hue = "survival_status", height = 4)\
   .map(plt.scatter, "ptent_age", "axillary_nodes")\
   .add_legend()
plt.show()

# %% [markdown]
# We can't classify using this combination as its completely mixed up.
# So lets see some other combination

# %%
sns.set_style("whitegrid")
sns.FacetGrid(df, hue = "survival_status", height = 4)\
   .map(plt.scatter, "oper_yr", "axillary_nodes")\
   .add_legend()
plt.show()

# %% [markdown]
# seems this combination is also not going to contribute anything regarding classificaton -
#
# ## let's see pair plot using that we can say which combination is important or not any combination is going to be important

# %%
plt.close()
sns.set_style("whitegrid");
sns.pairplot(df, hue = "survival_status", height = 4)
plt.show()

# %% [markdown]
# <b>From the above graph the important combination is graph between number of positive axillary nodes and treatment year because we see better seperation than other combinations.</b>

# %%
df_yes = df.loc[df["survival_status"]=="yes"];
df_no = df.loc[df["survival_status"]=="no"];
plt.plot(df_yes["axillary_nodes"], np.zeros_like(df_yes['axillary_nodes']))
plt.plot(df_no["axillary_nodes"], np.zeros_like(df_no['axillary_nodes']))
plt.show()

# %%
counts, bin_edges = np.histogram(df_yes['axillary_nodes'], bins = 10, density = True)
pdf = counts/(sum(counts))
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
plt.show()

# %%
print(np.median(df_yes["axillary_nodes"]))
print(np.median(df_no["axillary_nodes"]))
# Out:
# 0.0
# 4.0

# %%
df.describe()
# Out:
#         ptent_age     oper_yr  axillary_nodes
# count  305.000000  305.000000      305.000000
# mean    52.531148   62.849180        4.036066
# std     10.744024    3.254078        7.199370
# min     30.000000   58.000000        0.000000
# 25%     44.000000   60.000000        0.000000
# 50%     52.000000   63.000000        1.000000
# 75%     61.000000   66.000000        4.000000
# max     83.000000   69.000000       52.000000

# %%
print(np.percentile(df_yes["axillary_nodes"], 75))
print(np.percentile(df_yes["axillary_nodes"], 79))
print(np.percentile(df_yes["axillary_nodes"], 80))
print(np.percentile(df_yes["axillary_nodes"], 90))
# Out:
# 3.0
# 3.170000000000016
# 4.0
# 8.0

# %% [markdown]
# ## Conclusion -
#
# 1. Almost 80% of the patient(which survived more than 5 years) are having less than 4 positive axillary nodes.
# 2. the important combination is graph between number of positive axillary nodes and treatment year because we see better seperation than other combinations.
# 3. Patient whose treatment year is below 1960 are having lesser chance of surviving more than 5 years and whose treatment year is more than 1965 are having higher chances of surviving more than 5 years.
